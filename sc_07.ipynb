# %%
# 쥬피터노트북 셀 스타일 조절 
from IPython.core.display import display, HTML
display(HTML("<style>.container { font-weight: bold !important; }</style>"))
display(HTML("<style>.container { width: 100% !important; }</style>"))

# 경고 메세지 숨기기 
import warnings
warnings.filterwarnings(action='ignore')
# Out:
# C:\Users\pmpkc\AppData\Local\Temp\ipykernel_6136\829985655.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { font-weight: bold !important; }</style>
# <style>.container { width: 100% !important; }</style>

# %% [markdown]
# # Selenium을 이용한 동적 컨텐츠 수집
#
# - 참조 : Scrap_수업자료10_Selenium.html
# - 동적 컨텐츠
#
# ## 작업환경 설정
#
# -  설치 과정
#
# ```
# 1) 크롬 웹브라우저 버전 확인
#    1시방향 옵션 버튼 클릭 후 [도움말]-[Chrome 정보] 확인
#    버전은? 예)버전 102.0.5005.63(공식 빌드)
#
# 2) 크롬 웹브라우저 버전에 맞는 드라이버 파일 다운로드
#    https://chromedriver.chromium.org/downloads
#
#    윈도우용인 경우 :   chromedriver_win32.zip
#
#    쥬피터노트북 파일이 있는 폴더에 압축해제한다.
#    chromedriver.exe 파일이 있는지 확인
#
# 3) 셀레니움 설치
#    pip list 로 selenium 이 있는지 확인
#
#    없으면 설치
#    pip install selenium
#
#  ```

# %%
# chromedriver.exe 파일이 있는지 확인

# %%
# ls

# %%
#  pip list 로 selenium 이 있는지 확인

# %%
# pip list

# %%
# 없으면 설치

# %%
# pip install selenium

# %%
# 1) 관련 모듈 임포트 
import pandas as pd
import time
from selenium import webdriver

# %%
webdriver
# Out:
# <module 'selenium.webdriver' from 'C:\\Users\\pmpkc\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\selenium\\webdriver\\__init__.py'>

# %% [markdown]
# ## 구글 검색엔진에서 검색어 결과 저장하기
#
# - 크롬웹브라우저가 실행된다.
# - 특정 url(google.com)로 이동한다
# - 검색어를 입력한다.
# - 검색어 결과 페이지에서 특정 요소를 접근한다.
# - 리스트에 저장한다.
# - 데이타프레임으로 변경한다.
# - csv 파일로 저장한다

# %%
# 2) 셀레니움 드라이버 객체 생성 후 크롬 웹브라우저 구동 
# 드라이버객체명 = webdriver.Chrome('chromedriver.exe 경로')

# 윈도우용
driver = webdriver.Chrome('chromedriver.exe')

# %%
# 3) 지연시간 지정 후에 웹브라우저 주소로 이동 
# 지연시간 주기 time.sleep(시간)
time.sleep(2)
# 이동 URL 
url = 'http://www.google.com'
# 드라이버객체명.get(이동URL )
driver.get(url)

# %% [markdown]
# ### 셀레니움 메소드와 속성
#
# - 드라이버객체.find_element_by_name(name속성값) => 객체 1개
#
# name 값으로 요소 추출
#
# - 드라이버객체.find_element_by_css_selector(선택자) => 객체1개
#
# 첫번째 선택자로 요소 추출
#
# bs의 select_one()과 동일
#
# - 드라이버객체.find_elements_by_css_selector(선택자) => 객체리스트
#
# bs의 select()과 동일
#
# - 텍스트 접근
#
# text => 내용텍스트
#
# - 속성값 접근
# get_attribute(속성) => 속성값

# %% [markdown]
# ### 이벤트(동작)
# - 동작은?
# - send_keys(키워드) : 텍스트필드에 값을 입력하는 이벤트
# - click() => 선택자 요소 클릭
# - submit() => 전송이벤트

# %%
# 4) 검색어 입력 
# 원격 크롬웹브라우저에 입력한 검색어 결과가 출력되어야 한다. 

time.sleep(2)

# q는 검색 입력창의 name 값 
driver.find_element_by_name('q').send_keys('파이썬')
driver.find_element_by_name('q').submit()

# %% [raw]
# # 검색창 소스
# # input 태그 = name 값으 q
# <input class="gLFyf gsfi" jsaction="paste:puy29d;"
# maxlength="2048" name="q" type="text"
# aria-autocomplete="both" aria-haspopup="false"
# autocapitalize="off" autocomplete="off"
# autocorrect="off" autofocus=""
# role="combobox" spellcheck="false"
# title="검색" value="" aria-label="검색"
# data-ved="0ahUKEwjBz7Pi0I34AhWFxGEKHdc1D08Q39UDCAY">

# %%
# 5) 검색된 결과 페이지에서 제목, URL 정보 추출 

# 선택자를 가진 첫번째 요소 => 1개의 객체 
target1 = driver.find_element_by_css_selector('div.yuRUbf')
# 선택자를 가진 모든 요소  => 리스트 
target2 = driver.find_elements_by_css_selector('div.yuRUbf')

print(target1)
print('='*50)
print(len(target2))
print(target2)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="9fc09397fd0c8bf1aad5ab5779088ded", element="a45ae2c5-46af-48ff-89e9-51bb6e6cf665")>
# ==================================================
# 8
# [<selenium.webdriver.remote.webelement.WebElement (session="9fc09397fd0c8bf1aad5ab5779088ded", element="a45ae2c5-46af-48ff-89e9-51bb6e6cf665")>, <selenium.webdriver.remote.webelement.WebElement (session="9fc09397fd0c8bf1aad5ab5779088ded", element="065ada28-f9ae-4be8-aefc-8fd7c667c395")>, <selenium.webdriver.remote.webelement.WebElement (session="9fc09397fd0c8bf1aad5ab5779088ded", element="a63986ab-b37b-47b0-97d8-91e6cdb21212")>, <selenium.webdriver.remote.webelement.WebElement (session="9fc09397fd0c8bf1aad5ab5779088ded", element="f86b2739-820b-4028-aa83-d7dc3fe6c164")>, <selenium.webdriver.remote.webelement.WebElement (session="9fc09397fd0c8bf1aad5ab5779088ded", element="b788e0aa-860c-4cac-af05-a2169db59f6f")>, <selenium.webdriver.remote.webelement.WebElement (session="9fc09397fd0c8bf1aad5ab5779088ded", element="104d4728-e245-4370-b2a7-0a13386e3e39")>, <selenium.webdriver.remote.webelement.WebElement (session="9fc09397fd0c8bf1aad5ab5779088ded", element="a630093c-7266-4f9d-8b22-cb2209a4b205")>, <selenium.webdriver.remote.webelement.WebElement (session="9fc09397fd0c8bf1aad5ab5779088ded", element="cc106e76-3ca2-4ac6-97d6-32c92d82d197")>]

# %% [raw]
# # 관련 소스 파악
# div.yuRUbf > a > h3

# %%
# 한개의 객체에서 내용과 속성값 추출 
print(target1)
print()
print(target1.text)
print()
# h3 태그안의 텍스트만 
print(target1.find_element_by_css_selector('h3'))
print()
print(target1.find_element_by_css_selector('h3').text)
# a 태그안의 href 속성값 추출 
print('='*50)
print(target1.get_attribute('href'))
print(target1.find_element_by_css_selector('a').get_attribute('href'))
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="9fc09397fd0c8bf1aad5ab5779088ded", element="a45ae2c5-46af-48ff-89e9-51bb6e6cf665")>
#
# 파이썬 자습서 — Python 3.10.4 문서
# https://docs.python.org › tutorial
#
# <selenium.webdriver.remote.webelement.WebElement (session="9fc09397fd0c8bf1aad5ab5779088ded", element="ce3099d1-8ca0-449e-a74f-6b6224e0cc12")>
#
# 파이썬 자습서 — Python 3.10.4 문서
# ==================================================
# None
# https://docs.python.org/ko/3/tutorial/index.html

# %%
# 6) 리스트 객체에서 요소 추출 => 2차원 리스트 저장 
print(type(target2))
# 출력만 
for div in target2:
    print('제목 => ', div.find_element_by_css_selector('h3').text )
    print('URL => ', div.find_element_by_css_selector('a').get_attribute('href') )
    print('='*30)

# 리스트 생성 후 저장 
result_list = []
for div in target2:
    title = div.find_element_by_css_selector('h3').text
    url = div.find_element_by_css_selector('a').get_attribute('href')
    result_list.append([title, url])

print(len(result_list))
# Out:
# <class 'list'>
# 제목 =>  파이썬 자습서 — Python 3.10.4 문서
# URL =>  https://docs.python.org/ko/3/tutorial/index.html
# ==============================
# 제목 =>  Welcome to Python.org
# URL =>  https://www.python.org/
# ==============================
# 제목 =>  파이썬 - 위키백과, 우리 모두의 백과사전
# URL =>  https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC
# ==============================
# 제목 =>  1. 파이썬 시작하기 - 왕초보를 위한 Python - 위키독스
# URL =>  https://wikidocs.net/43
# ==============================
# 제목 =>  Python - 나무위키
# URL =>  https://namu.wiki/w/Python
# ==============================
# 제목 =>  파이썬(Python) 바로 알기 – 특징, 장점, 활용 사례 - 가비아 ...
# URL =>  https://library.gabia.com/contents/9256/
# ==============================
# 제목 =>  모두를 위한 프로그래밍 : 파이썬 강좌소개 - edwith
# URL =>  https://www.edwith.org/pythonforeverybody
# ==============================
# 제목 =>  [미디어] 파이썬, 남들 다 한다고 시작하나요? 이럴 때 배우세요.
# URL =>  https://fastcampus.co.kr/story_article_pythontop3
# ==============================
# 8

# %%
# 7) 데이타프레임으로 변경한 후 csv 파일로 저장 
df = pd.DataFrame(result_list, columns=['제목', 'URL'])
df.to_csv('output/google_파이썬.csv', index=False)
df
# Out:
#                                             제목  \
# 0                   파이썬 자습서 — Python 3.10.4 문서
# 1                        Welcome to Python.org
# 2                      파이썬 - 위키백과, 우리 모두의 백과사전
# 3          1. 파이썬 시작하기 - 왕초보를 위한 Python - 위키독스
# 4                                Python - 나무위키
# 5  파이썬(Python) 바로 알기 – 특징, 장점, 활용 사례 - 가비아 ...
# 6             모두를 위한 프로그래밍 : 파이썬 강좌소개 - edwith
# 7        [미디어] 파이썬, 남들 다 한다고 시작하나요? 이럴 때 배우세요.
#
#                                                  URL
# 0   https://docs.python.org/ko/3/tutorial/index.html
# 1                            https://www.python.org/
# 2  https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%...
# 3                            https://wikidocs.net/43
# 4                         https://namu.wiki/w/Python
# 5           https://library.gabia.com/contents/9256/
# 6          https://www.edwith.org/pythonforeverybody
# 7  https://fastcampus.co.kr/story_article_pythontop3

# %%
ls output
# Out:
#  C 드라이브의 볼륨: Windows-SSD
#  볼륨 일련 번호: F2DA-E15C
#
#  C:\Users\pmpkc\Desktop\bsu\workspace202205\1_Scrap\output 디렉터리
#
# 2022-06-02  오후 12:26    <DIR>          .
# 2022-06-02  오전 11:54    <DIR>          ..
# 2022-05-31  오전 10:45             1,432 bestbook.csv
# 2022-05-30  오후 05:24            12,444 color.csv
# 2022-05-30  오전 10:41            14,953 google.html
# 2022-06-02  오후 12:26               791 google_파이썬.csv
# 2022-05-31  오후 01:01             1,514 신과함께1.csv
# 2022-05-31  오후 01:26             4,986 신과함께2.csv
# 2022-05-31  오후 02:26            11,555 키드.csv
#                7개 파일              47,675 바이트
#                2개 디렉터리  171,790,942,208 바이트 남음

# %% [markdown]
# ## 다음 페이지로 이동
#
# - 다음 페이지로 이동하는 [다음] 버튼 요소 소스 파악
# - [다음] 버튼 클릭

# %% [raw]
# # 소스 파악
# a#pnnext > span {다음}

# %%
target_next = driver.find_element_by_css_selector('a#pnnext')
target_next
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="9fc09397fd0c8bf1aad5ab5779088ded", element="541752fa-7c5a-4ea5-a3db-bd944464a2c5")>

# %%
# 다음 페이지 주소 추출
target_next.get_attribute('href')
# Out:
# 'https://www.google.com/search?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC&ei=4C2YYrTcIpWD2roPk76HoAU&start=10&sa=N&ved=2ahUKEwi0zJ-Q6Y34AhWVgVYBHRPfAVQQ8NMDegQIAhBO'

# %%
# [다음] 버튼 클릭 
time.sleep(2)
target_next = driver.find_element_by_css_selector('a#pnnext')
target_next.click()

# %% [markdown]
# # 전체 검색 결과 저장하기
#
# 1) 관련 모듈 임포트
# 2) 드라이버객체 생성 => 크롬웹브라우저 실행
# 3) 구글 사이트로 이동
# 4) 검색어 입력 후 검색 결과 페이지로 이동
# 5) 셀레니움 메서드를 이용하여 추출 영역 부분을 변수로 저장 => 셀레니움 리스트
# 6) 5번에서 제목, url 정보를 추출하여 리스트에 저장
# 7) 다음 페이지로 이동하는 버튼 부분을 추출. click() 이벤트로 다음 페이지로 이동
# 8) 5~7번 과정 반복. 맨 마지막 페이지라면 제어문 밖으로 이동해서 최종 결과 출력
# '''

# %%
# 2) 셀레니움 드라이버 객체 생성 후 크롬 웹브라우저 구동 
# 드라이버객체명 = webdriver.Chrome('chromedriver.exe 경로')

# 윈도우용
driver = webdriver.Chrome('chromedriver.exe')

# 지연시간 주기 time.sleep(시간)
time.sleep(2)
# 이동 URL 
url = 'http://www.google.com'
# 드라이버객체명.get(이동URL )
driver.get(url)

# 4) 검색어 입력 
# 원격 크롬웹브라우저에 입력한 검색어 결과가 출력되어야 한다. 

time.sleep(2)

# q는 검색 입력창의 name 값 
driver.find_element_by_name('q').send_keys('파이썬')
driver.find_element_by_name('q').submit()

# %%
# 5) 전체 페이지 저장
# 빈 리스트 생성 
# while True구문 이용해서 반복문, 다음버튼이 나오지 않을때 까지 a#pnnext
# 마지막 페이지는 [다음]버튼이 없음

# %%
# 전체 페이지 번호만 출력하기


page = 1
while True:
    print(page, '페이지')
    # 다음 버튼 요소 추출 
    time.sleep(2)
    try:
        target_next = driver.find_element_by_css_selector('a#pnnext')
        target_next.click()
        time.sleep(2)
        # 페이지 번호 증가 
        page += 1
    except:
        time.sleep(1)
        print('마지막 페이지')
        break
# Out:
# 1 페이지
# 마지막 페이지

# %%
# 전체 페이지를 순회하면서 2차원 리스트에 저장


page = 1

#빈리스트 생성
result_list = []

while True:
    print(page, '페이지')
    
    # 선택자를 가진 모든 요소 > 리스트
    target_list = driver.find_elements_by_css_selector('div.yuRUbf')
    time.sleep(2)
    
    for div in target_list:
        title = div.find_element_by_css_selector('h3').text
        url = div.find_element_by_css_selector('a').get_attribute('href')
        result_list.append([title, url])
    
    try:
        target_next = driver.find_element_by_css_selector('a#pnnext')
        target_next.click()
        time.sleep(2)
        # 페이지 번호 증가 
        page += 1
    except:
        time.sleep(1)
        print('마지막 페이지')
        break
# Out:
# 1 페이지
# 2 페이지
# 3 페이지
# 4 페이지
# 5 페이지
# 6 페이지
# 7 페이지
# 8 페이지
# 9 페이지
# 10 페이지
# 11 페이지
# 12 페이지
# 마지막 페이지

# %%
# 데이타 프레임으로 변환, 저장

print(len(target_list))
df = pd.DataFrame(result_list, columns=['제목', 'URL'])
df.to_csv('output/google_파이썬2.csv', index=False)
df
# Out:
# 10
#                                              제목  \
# 0                    파이썬 자습서 — Python 3.10.4 문서
# 1                         Welcome to Python.org
# 2                       파이썬 - 위키백과, 우리 모두의 백과사전
# 3           1. 파이썬 시작하기 - 왕초보를 위한 Python - 위키독스
# 4                                 Python - 나무위키
# ..                                          ...
# 113  Ternary Operator in Python - GeeksforGeeks
# 114   Solo Learn (Python) - Courses | Sololearn
# 115            2021년 상위 10개 프로그래밍 언어 - Laptop28
# 116       pandas 1.4.2 documentation - PyData |
# 117  [백준] 10814번 나이순 정렬 (C++, Python) - 코드 아카이브
#
#                                                    URL
# 0     https://docs.python.org/ko/3/tutorial/index.html
# 1                              https://www.python.org/
# 2    https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%...
# 3                              https://wikidocs.net/43
# 4                           https://namu.wiki/w/Python
# ..                                                 ...
# 113          https://www.geeksforgeeks.org/data-types/
# 114            https://www.sololearn.com/learning/1073
# 115  https://laptop28.com/ko/2021%EB%85%84-%EC%83%8...
# 116                    https://pandas.pydata.org/docs/
# 117                 https://reo91004.tistory.com/m/132
#
# [118 rows x 2 columns]
