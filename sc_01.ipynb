# %% [markdown]
# --  수업 셋팅
# 아이콘 실행이 되지 않는 경우에는
# 아나콘다 설치 참조
# https://codepathfinder.com/entry/Python-%EC%95%84%EB%82%98%EC%BD%98%EB%8B%A4Anaconda-%EC%84%A4%EC%B9%98%ED%95%98%EA%B8%B0
#
# Advanced Installation Options  체크박스가 선택되어야함
#
#
# 1) 작업폴더 생성
# 영문과 숫자 조합(한글안됨)
# 예)  workspace202205
#
# 2) 수업자료는 1)의 작업폴더안에 별도 셋팅
# 예)  C:\workspace202205\step1_scrap
#
# 3) 아나콘다 설치 확인
#
# 4) 쥬피터노트북 시작폴더 셋팅
#
# C:\workspace202205
#
# a)  아나콘다 설치 폴더 확인
#
# 예시1) C:\ProgramData\Anaconda3
# 예시2) C:\사용자\~\Anaconda3
#
# C:\ProgramData\Anaconda3\Scripts\jupyter-notebook.exe
#
# b) jupyter-notebook.exe 마우스 우측 버튼 클릭 후
# [보내기]-[바탕화면에 바로가기 만들기]
#
# c) 바탕화면에 생성된 아이콘을 마우스 우측 버튼 클릭
# [속성] 클릭
#
# d) 대화상자에서
# [시작 위치] 경로를 쥬피터노트북 파일이 생성되는 위치로 설정
# 예) C:\workspace202205

# %% [markdown]
# # 쥬피터노트북 셀 스타일 조절
# from IPython.core.display import display, HTML
# display(HTML("<style>.container { font-weight: bold !important; }</style>"))
# display(HTML("<style>.container { width: 100% !important; }</style>"))
#
# # 경고 메세지 숨기기
# import warnings
# warnings.filterwarnings(action='ignore')

# %%
# requests 모듈 확인 
# pip list 
# requests 확인

# %%
# 모듈 임포트 
import requests

# %%
# 모듈 버전 확인 
requests.__version__
# Out:
# '2.27.1'

# %%
# 설치는?

# pip install requests

# %%
# 모듈에서 제공하는 메소드와 속성확인
# dir(모듈명) -> 리스트로 반환
# dir(requests)
print(dir(requests), len(dir(requests)))
# Out:
# ['ConnectTimeout', 'ConnectionError', 'DependencyWarning', 'FileModeWarning', 'HTTPError', 'JSONDecodeError', 'NullHandler', 'PreparedRequest', 'ReadTimeout', 'Request', 'RequestException', 'RequestsDependencyWarning', 'Response', 'Session', 'Timeout', 'TooManyRedirects', 'URLRequired', '__author__', '__author_email__', '__build__', '__builtins__', '__cached__', '__cake__', '__copyright__', '__description__', '__doc__', '__file__', '__license__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__title__', '__url__', '__version__', '_check_cryptography', '_internal_utils', 'adapters', 'api', 'auth', 'certs', 'chardet_version', 'charset_normalizer_version', 'check_compatibility', 'codes', 'compat', 'cookies', 'delete', 'exceptions', 'get', 'head', 'hooks', 'logging', 'models', 'options', 'packages', 'patch', 'post', 'put', 'request', 'session', 'sessions', 'ssl', 'status_codes', 'structures', 'urllib3', 'utils', 'warnings'] /n 69

# %%
# 웹페이지에 접근 (parsing)
# 1) 요청 주소 지정 
url = "http://google.com"

# 2) get 방식으로 요청 
# get(url)
res = requests.get(url)
# 200이 출력되면 성공 
res
# Out:
# <Response [200]>

# %%
# 객체 출력
print(res, type(res))

# 인코딩과 헤더 출력
res.encoding, res.headers
# Out:
# <Response [200]> <class 'requests.models.Response'>
# ('ISO-8859-1',
#  {'Date': 'Mon, 30 May 2022 01:30:30 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Content-Type': 'text/html; charset=ISO-8859-1', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'Content-Length': '6451', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': '1P_JAR=2022-05-30-01; expires=Wed, 29-Jun-2022 01:30:30 GMT; path=/; domain=.google.com; Secure, AEC=AakniGN_MpE2VVIsYdknRuHZIqgvRjBb7RpNELlbdsao9P66d4MY2BFSCA; expires=Sat, 26-Nov-2022 01:30:30 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax, NID=511=VNsw9hfdDgNYhoR49KjOGTmgnz-FYFccLR7QYZVyfi_IJ14Dw8KOiJCODKDTxAadSgHNcbMVDd1ix7d4N5GhM8ZWVwNZe4niGpsTG5b2dlgQjxHve8GkNHETzpBdHdaMV4OmTvvy6EqhY80Smlg7ACsFofBeAPrD_RUhZgTY6ZI; expires=Tue, 29-Nov-2022 01:30:30 GMT; path=/; domain=.google.com; HttpOnly'})

# %%
# 3) 페이지 소스 => 텍스트화 (text or string)
html_str = res.text
print(type(html_str))
html_str
# Out:
# <class 'str'>
# ...

# %%
# 4) html 파일 저장
# 아웃풋 폴더 생성
# mk = make, dir = directory

# import os
# os.mkdir('output')

# %%
# 폴더 생성 및 파일 목록 확인(ls 외 다른 명령어는 에러발생, 주피터에서만 사용가능)

# %%
ls
# Out:
#  C 드라이브의 볼륨: Windows-SSD
#  볼륨 일련 번호: F2DA-E15C
#
#  C:\Users\pmpkc\Desktop\bsu\workspace202205\1_Scrap 디렉터리
#
# 2022-05-30  오전 10:38    <DIR>          .
# 2022-05-30  오전 09:25    <DIR>          ..
# 2022-05-30  오전 10:04    <DIR>          .ipynb_checkpoints
# 2022-05-30  오전 10:38            24,099 1.sc_01.ipynb
# 2022-05-30  오전 10:37    <DIR>          output
# 2022-05-30  오전 09:23         5,539,853 Scrap.zip
# 2022-05-30  오전 09:24           607,653 Scrap_수업자료1_urllib_requests.html
# 2022-05-30  오전 09:24           583,805 Scrap_수업자료2_HTML.html
# 2022-05-30  오전 09:24           572,592 Scrap_수업자료3_CSS.html
# 2022-05-30  오전 09:24           721,262 Scrap_수업자료4_BS4.html
# 2022-05-30  오전 09:24           618,448 Scrap_수업자료5_BS4_color.html
# 2022-05-30  오전 09:24           602,724 Scrap_수업자료6_BS4_Yes24.html
# 2022-05-30  오전 09:24           579,602 Scrap_수업자료7_BS4_퀴즈.html
# 2022-05-30  오전 09:24           623,107 Scrap_수업자료8_BS4_네이버댓글.html
# ...

# %%
# output 폴더 생성 확인
# html 파일 저장
with open('output/google.html', 'w', encoding = 'ISO-8859-1') as f:
    f.write(html_str)

# %%
ls output
# Out:
#  C 드라이브의 볼륨: Windows-SSD
#  볼륨 일련 번호: F2DA-E15C
#
#  C:\Users\pmpkc\Desktop\bsu\workspace202205\1_Scrap\output 디렉터리
#
# 2022-05-30  오전 10:41    <DIR>          .
# 2022-05-30  오전 10:41    <DIR>          ..
# 2022-05-30  오전 10:41            14,953 google.html
#                1개 파일              14,953 바이트
#                2개 디렉터리  174,123,503,616 바이트 남음

# %%
# html 저장 확인
# 텍스트파일 원본을 쥬피터에서 확인하려면?
# !type 경로

# %%
# !type output\google.html
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="_8uS6KBCC7laKTJbk_IVGA">(function(){window.google={kEI:'Nh6UYuLYCOKUr7wPopugiAg',kEXPI:'0,18167,1284369,56873,6059,206,4804,2316,383,246,5,1354,4013,1123753,1197753,648,302561,77529,16114,28684,17572,4859,1361,9291,3029,2815,1929,12835,4020,978,13228,3847,10623,12723,2039,7349,629,5081,1593,1279,2453,289,149,1103,840,2197,4100,3514,606,2023,2297,14670,3227,2845,7,4774,34,12642,16320,1851,2614,13142,3,346,230,6460,148,13975,4,1528,2304,7039,20309,4764,2658,7356,18096,16786,5824,2533,4094,4052,3,3541,1,39042,2,3110,2,14022,14116,11623,5679,1020,2381,2719,18296,2,6,7718,4569,6255,23421,830,422,5835,5673,2,6525,2767,4333,19,4998,1073,1394,445,2,2,1,6959,3831,166,15239,1,436,8155,6401,181,627,112,60,3043,11637
# ...

# %% [markdown]
# # Urllib를 이용한 웹페이지 요청
# - 내장 라이브러리 따라서 pip install(x)

# %%
# 0) 모듈 임포트
from urllib.request import urlopen
# 문법확인
# 메서드?
# 메서드()
# 혹은 shift + tab

# %%
urlopen?
# Out:
# Signature:
# urlopen(
#     url,
#     data=None,
#     timeout=<object object at 0x0000025450A94B60>,
#     *,
#     cafile=None,
#     capath=None,
#     cadefault=False,
#     context=None,
# )
# Docstring:
# Open the URL url, which can be either a string or a Request object.
#
# *data* must be an object specifying additional data to be sent to
# the server, or None if no such data is needed.  See Request for
# details.
#
# urllib.request module uses HTTP/1.1 and includes a "Connection:close"
# header in its HTTP requests.
#
# The optional *timeout* parameter specifies a timeout in seconds for
# blocking operations like the connection attempt (if not specified, the
# global default timeout setting will be used). This only works for HTTP,
# HTTPS and FTP connections.
#
# If *context* is specified, it must be a ssl.SSLContext instance describing
# the various SSL options. See HTTPSConnection for more details.
#
# ...

# %%
# 1) 페이지 요청 > 객체화
url = 'https://google.com'
res = urlopen(url)
res

# %%
res.status, res.headers, res.getheaders()
# Out:
# (200,
# ...
#  [('Date', 'Mon, 30 May 2022 01:52:26 GMT'),
#   ('Expires', '-1'),
#   ('Cache-Control', 'private, max-age=0'),
#   ('Content-Type', 'text/html; charset=ISO-8859-1'),
#   ('P3P', 'CP="This is not a P3P policy! See g.co/p3phelp for more info."'),
#   ('Server', 'gws'),
#   ('X-XSS-Protection', '0'),
#   ('X-Frame-Options', 'SAMEORIGIN'),
#   ('Set-Cookie',
#    '1P_JAR=2022-05-30-01; expires=Wed, 29-Jun-2022 01:52:26 GMT; path=/; domain=.google.com; Secure'),
#   ('Set-Cookie',
#    'AEC=AakniGNbSfzd4FnMcQwPfcJb3dGNcGAOPsL6_I8Sk9-gzXiZl36TydoBRDw; expires=Sat, 26-Nov-2022 01:52:26 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax'),
#   ('Set-Cookie',
#    'NID=511=kA9yjjCNK3RfxT11bHOYFGeI05VkgrwHz_mc7o8pFAdboqpyCI_z5dXf9clCoTo6GIzDGFEK6M_OThb1AIPaS5cBhhmbjGCEtuQgKdxfprB47bQZsbvNA-putlhx9XZvQ4scLuG7asajZhpHlAvDWg3BIxM_W6pk0R5rGd0n618; expires=Tue, 29-Nov-2022 01:52:26 GMT; path=/; domain=.google.com; HttpOnly'),
#   ('Alt-Svc',
# ...

# %%
# 2) res 객체에서 html 소스 저장
html_str2 = res.read()
type(html_str2)
# Out:
# bytes

# %%
html_str2  # bytes는 맨앞에 b'가 찍힌다.
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="n8Lg0t9Kqmgjxbk9q-NIQg">(function(){window.google={kEI:\'WiOUYpGjKtiM-AbT7p_QBA\',kEXPI:\'0,1302536,56873,6058,207,4804,2316,383,246,5,1354,4013,1123753,1197706,695,380089,16115,17444,11240,17572,4859,1361,9291,3021,17587,4020,978,13228,3847,10622,7432,15309,5081,1593,1279,2742,149,1103,840,6297,3514,606,2023,1777,520,14670,3227,2845,7,5599,11851,16320,1851,2614,13142,3,346,230,6459,149,13975,4,1528,2304,7039,25073,2658,7357,13658,4437,16786,5815,2542,4094,4052,3,3541,1,42154,2,14022,6249,7867,11623,5679,1020,2380,2719,18279,2,6,7736,4569,6255,23421,1252,5835,14968,4332,19,4225,1845,853,542,445,2,2,1,24626,1569,1,436,1463,6692,2566,3835,181,637,162,2449,593,859,7872,2907,7341,3217,11247,1920,773,2414,15
# ...
